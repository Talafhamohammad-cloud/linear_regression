# %% [markdown]
# # linear regression

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
DataFrame = pd.read_csv('./Linear Regression - Sheet1.csv')
DataFrame.head(5)
# Out:
#    X         Y
# 0  1  3.888889
# 1  2  4.555556
# 2  3  5.222222
# 3  4  5.888889
# 4  5  6.555556

# %%
DataFrame.describe()
# Out:
#                 X           Y
# count  300.000000  300.000000
# mean   150.500000  102.215556
# std     86.746758   57.842711
# min      1.000000    1.888889
# 25%     75.750000   52.388889
# 50%    150.500000  102.222222
# 75%    225.250000  152.055556
# max    300.000000  201.888889

# %%
DataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       300 non-null    int64
#  1   Y       300 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 4.8 KB

# %% [markdown]
# # this data dose not contain date col to be in datetime

# %%
x = DataFrame['X'].values
y = DataFrame['Y'].values

# %%
x = x.reshape(-1, 1)
y = y.reshape(-1, 1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, test_size=0.2, random_state=100)
print(f'x_train shape{x_train.shape}')
print(f'x_train shape{x_test.shape}')
print(f'y_train shape{y_train.shape}')
print(f'y_train shape{y_test.shape}')
print(y_test)
# Out:
# x_train shape(240, 1)
# x_train shape(60, 1)
# y_train shape(240, 1)
# y_train shape(60, 1)
# [[151.8888889 ]
#  [ 96.55555556]
#  [147.8888889 ]
#  [137.8888889 ]
#  [169.8888889 ]
#  [ 93.22222222]
#  [ 89.22222222]
#  [ 62.55555556]
#  [ 21.88888889]
#  [195.8888889 ]
#  [109.8888889 ]
#  [  8.55555556]
#  [141.2222222 ]
#  [135.2222222 ]
#  [111.8888889 ]
#  [ 15.88888889]
#  [191.8888889 ]
#  [149.2222222 ]
#  [ 43.88888889]
#  [201.8888889 ]
#  [137.2222222 ]
#  [117.8888889 ]
#  [103.2222222 ]
#  [107.8888889 ]
#  [143.8888889 ]
#  [114.5555556 ]
#  [136.5555556 ]
#  [135.8888889 ]
#  [ 78.55555556]
#  [116.5555556 ]
#  [157.8888889 ]
#  [115.8888889 ]
#  [ 13.88888889]
#  [151.2222222 ]
#  [157.2222222 ]
#  [ 98.55555556]
#  [177.8888889 ]
#  [ 77.22222222]
#  [ 34.55555556]
#  [123.2222222 ]
#  [ 53.88888889]
#  [131.2222222 ]
#  [ 41.22222222]
#  [ 86.55555556]
#  [ 77.88888889]
#  [194.5555556 ]
#  [133.8888889 ]
#  [ 10.55555556]
#  [ 87.22222222]
#  [169.2222222 ]
# ...

# %%
# %matplotlib inline
plt.scatter(x_train, y_train, color='blue')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('talafha-plot')
plt.show()

# %%
lm = LinearRegression()
lm.fit(x_train, y_train)
y_predict = lm.predict(x_test)
print(f"Train accuracy {round(lm.score(x_train,y_train)*100,2)} %")
print(f"Test accuracy {round(lm.score(x_test,y_test)*100,2)} %")
# Out:
# Train accuracy 90.46 %
# Test accuracy 99.65 %

# %%
plt.scatter(x_train, y_train, color='green')
plt.plot(x_test, y_predict)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Trained model plot")
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
x = 350
y_predict = lm.predict([[x]])[0]
print(f"if the expected value will be {x} then its is predicted to be {int(y_predict)}")
# Out:
# if the expected value will be 350 then its is predicted to be 228

# %%
x_predict=lm.predict(y_test)

# %%
plt.scatter(x_train, y_train)
plt.scatter(y_test, x_predict, color='red')
plt.plot(x_test, y_predict, color='blue')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('T2')
plt.show()
